# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Dataset:
df=pd.read_csv('C:/Users/Azhar1/Documents/FlipRobo/Project_practise3/Grades.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA  \
# 0  ...     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      A      C      A      A      A     A-      A  3.608
# 3  ...      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B+     B+     B-     A-      A     A-     A-      A  3.448
#
#   Unnamed: 43
# 0         NaN
# 1         NaN
# 2         NaN
# ...

# %%
df.shape
# Out:
# (571, 44)

# %%
# Removing unnecessary columns:
df=df.drop(columns=['Seat No.'],axis=1)
df=df.drop(columns=['Unnamed: 43'],axis=1)

# %%
df.shape
# Out:
# (571, 42)

# %%
df.dtypes
# Out:
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# dtype: object

# %%
df.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
df.isnull().sum()
# Out:
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    object
#  1   HS-101     571 non-null    object
#  2   CY-105     570 non-null    object
#  3   HS-105/12  570 non-null    object
#  4   MT-111     569 non-null    object
#  5   CS-105     571 non-null    object
#  6   CS-106     569 non-null    object
#  7   EL-102     569 non-null    object
#  8   EE-119     569 non-null    object
#  9   ME-107     569 non-null    object
#  10  CS-107     569 non-null    object
#  11  HS-205/20  566 non-null    object
#  12  MT-222     566 non-null    object
#  13  EE-222     564 non-null    object
#  14  MT-224     564 non-null    object
#  15  CS-210     564 non-null    object
#  16  CS-211     566 non-null    object
#  17  CS-203     566 non-null    object
#  18  CS-214     565 non-null    object
# ...

# %%
# Encoding the columns

from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()
df['PH-121']=LE.fit_transform(df['PH-121'])

# %%
df[['HS-101','CY-105']] = df[['HS-101','CY-105']].apply(LabelEncoder().fit_transform)

# %%
df[['HS-105/12','MT-111','CS-105','CS-106','EL-102','EE-119','ME-107','CS-107','HS-205/20','MT-222','EE-222','MT-224','CS-210','CS-211','CS-203','CS-214','EE-217','CS-212','CS-215','MT-331','EF-303','HS-304','CS-301','CS-302','TC-383','MT-442','EL-332','CS-318','CS-306','CS-312','CS-317','CS-403','CS-421','CS-406','CS-414','CS-419','CS-423','CS-412']] = df[['HS-105/12','MT-111','CS-105','CS-106','EL-102','EE-119','ME-107','CS-107','HS-205/20','MT-222','EE-222','MT-224','CS-210','CS-211','CS-203','CS-214','EE-217','CS-212','CS-215','MT-331','EF-303','HS-304','CS-301','CS-302','TC-383','MT-442','EL-332','CS-318','CS-306','CS-312','CS-317','CS-403','CS-421','CS-406','CS-414','CS-419','CS-423','CS-412']].apply(LabelEncoder().fit_transform)

# %%
df.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0       5      10       8          6       8      10       9       8       5
# 1       0       9      10          9       5       6       9       0      10
# 2       0       3       0          5       4       0       5       4       2
# 3       9       7      10          9       9       2      10       8       9
# 4       2       2       2          4       0       0       2       4       0
#
#    ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  CS-419  \
# 0       8  ...       8       8       8       8       2       0       8
# 1       9  ...      10       9       6       9       2       5       6
# 2       2  ...       3       3       0       6       0       0       0
# 3       7  ...      10       6      10       8       5       3       7
# 4       2  ...       5       4       4       5       2       0       2
#
#    CS-423  CS-412   CGPA
# 0       3       2  2.205
# ...

# %%
df.shape
# Out:
# (571, 42)

# %%
df.dtypes
# Out:
# PH-121         int32
# HS-101         int32
# CY-105         int32
# HS-105/12      int32
# MT-111         int32
# CS-105         int32
# CS-106         int32
# EL-102         int32
# EE-119         int32
# ME-107         int32
# CS-107         int32
# HS-205/20      int32
# MT-222         int32
# EE-222         int32
# MT-224         int32
# CS-210         int32
# CS-211         int32
# CS-203         int32
# CS-214         int32
# EE-217         int32
# CS-212         int32
# CS-215         int32
# MT-331         int32
# EF-303         int32
# HS-304         int32
# CS-301         int32
# CS-302         int32
# TC-383         int32
# MT-442         int32
# EL-332         int32
# CS-318         int32
# CS-306         int32
# CS-312         int32
# CS-317         int32
# CS-403         int32
# CS-421         int32
# CS-406         int32
# CS-414         int32
# CS-419         int32
# CS-423         int32
# CS-412         int32
# CGPA         float64
# dtype: object

# %%
df.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.781086    5.071804    2.921191    4.264448    3.935201    2.838879
# std      3.046895    2.785317    2.992228    3.216478    3.034481    2.696709
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    3.000000    0.000000    2.000000    2.000000    0.000000
# 50%      3.000000    5.000000    2.000000    4.000000    4.000000    2.000000
# 75%      6.000000    7.000000    5.000000    7.000000    6.000000    4.000000
# max     12.000000   11.000000   13.000000   13.000000   13.000000   10.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     4.161121    3.998249    3.921191    4.817863  ...    4.299475
# ...

# %%
df.corr()
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.382436  0.565773   0.508231  0.487830  0.609990
# HS-101     0.382436  1.000000  0.334536   0.473146  0.441847  0.400713
# CY-105     0.565773  0.334536  1.000000   0.516758  0.554936  0.587845
# HS-105/12  0.508231  0.473146  0.516758   1.000000  0.505049  0.493581
# MT-111     0.487830  0.441847  0.554936   0.505049  1.000000  0.416784
# CS-105     0.609990  0.400713  0.587845   0.493581  0.416784  1.000000
# CS-106     0.319649  0.321346  0.404763   0.516214  0.528063  0.310666
# EL-102     0.443420  0.359801  0.466034   0.373136  0.568940  0.377496
# EE-119     0.589250  0.323381  0.501859   0.425518  0.422151  0.522205
# ME-107     0.548820  0.345819  0.485183   0.334125  0.478874  0.464978
# CS-107     0.501814  0.507674  0.501331   0.550732  0.503985  0.530578
# HS-205/20  0.338530  0.200494  0.325533   0.224536  0.372303  0.229860
# ...

# %% [markdown]
# # Data Visualization

# %%
# Visualizing the count of CGPA
print(df['CGPA'].value_counts())
ax=sns.countplot(x='CGPA',data=df)
plt.show()
# Out:
# 3.019    5
# 3.058    3
# 2.793    3
# 3.443    3
# 2.206    3
#         ..
# 2.555    1
# 2.042    1
# 2.634    1
# 2.053    1
# 1.753    1
# Name: CGPA, Length: 491, dtype: int64

# %%
# Visualizing data distribution
plt.figure(figsize=(10,6),facecolor='white')
plotnumber=1
for col in df.columns:
    if plotnumber<=50:
        ax=plt.subplot(11,4,plotnumber)
        sns.distplot(df[col],color='m')
        plt.xlabel(col, fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidths=0.1,linecolor='black',annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
x=df.iloc[:,0:41]
x
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %% [markdown]
# # Using Linear Regression model as data is Continous

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
# Using Logistic Regression

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
lg=LinearRegression()
lg.fit(x_train,y_train)
predlg=lg.predict(x_test)
print('Mean absolute error:',mean_absolute_error(y_test,predlg))
print('Mean squared error:',mean_squared_error(y_test,predlg))
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predlg)))
# Out:
# Mean absolute error: 0.09173803883593665
# Mean squared error: 0.031100852519352913
# Root Mean squared error: 0.17635433796579236

# %%
lg = LinearRegression()
lg.fit(x_train, y_train)
lg_score_train = lg.score(x_train, y_train)
print("Training score: ",lg_score_train)
lg_score_test = lg.score(x_test, y_test)
print("Testing score: ",lg_score_test)
# Out:
# Training score:  0.9624771460520657
# Testing score:  0.9086884082649304

# %%
# R2 score to guage our model score/accuracy
from sklearn.metrics import r2_score
print(r2_score(y_test,predlg))
# Out:
# 0.9086884082649304

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(lg,'Project_Grades.pkl')
# Out:
# ['Project_Grades.pkl']

# %% [markdown]
# # Predicting the saved model

# %%
model=joblib.load('Project_Grades.pkl')

#Prediction
prediction=model.predict(x_test)
prediction
# Out:
# array([4.03517978, 3.50320296, 3.78507621, 3.26367506, 2.0667754 ,
#        2.49596294, 3.21689115, 2.94608466, 3.22786457, 2.43405966,
#        2.57340414, 2.27802558, 1.95396523, 2.71338296, 2.99531295,
#        3.35985169, 3.23153302, 3.94363177, 0.90261591, 3.3249333 ,
#        3.36110021, 3.07108171, 3.08284964, 3.64160512, 3.16042304,
#        3.09395074, 3.04076216, 3.60999083, 2.08622739, 3.76222046,
#        2.83755664, 2.94252637, 3.00260889, 2.86361531, 2.17190769,
#        3.35701121, 3.15885771, 3.081722  , 2.77781294, 3.20527744,
#        4.01557429, 1.97559144, 2.7217316 , 2.2710053 , 3.04271873,
#        3.57960184, 3.04824002, 2.53670157, 3.46560719, 2.92039137,
#        3.59267779, 2.6867661 , 2.7726393 , 2.83305614, 2.58639292,
#        2.52226156, 1.82204747, 1.32396257, 1.87630228, 3.80693444,
#        3.14878471, 2.85171217, 1.11788575, 3.28546416, 3.25779089,
#        2.11431182, 3.58511304, 2.74836299, 2.68524197, 3.13836142,
# ...
