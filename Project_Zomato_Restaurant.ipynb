# %% [markdown]
# In this dataset, we need to predict 2 things –
# 1) Average Cost for two
# 2) Price range

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %%
# Loading Dataset:
df1=pd.read_csv('C:\\Users/Azhar1/Documents/FlipRobo/Project_Evaluation/Project_Phase 3/Project_Zomato.csv', encoding='latin-1')

# %%
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.shape
# Out:
# (9551, 21)

# %%
df2 = pd.read_excel('C:/Users/Azhar1/Documents/FlipRobo/Project_Evaluation/Project_Phase 4/Country-Code.xlsx')
df2.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df=pd.merge(df1,df2,on='Country Code',how='left')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# The dimension of our data is 9551 rows * 22 columns

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
# We see that there are interger, float and object datatypes.

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#printing the unique values available in the dataset

for i in df.columns:
    print(df[i].value_counts())
    print('*'*75)
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
# ***************************************************************************
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
# ***************************************************************************
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# ...

# %%
#checking the number of null values present in each columns 

df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
# visualising null values in dataset
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# No null values presented graphically.

# %%
sns.countplot(x='Country Code',data=df)
plt.show()

# %% [markdown]
# Whose are having 1 as country code they are having more count.

# %%
sns.countplot(x='Price range',data=df)
plt.show()

# %% [markdown]
# We can see, Price range of 1 has maximum price range followed by 2.

# %%
sns.countplot(y='Currency',data=df)
# Out:
# <Axes: xlabel='count', ylabel='Currency'>

# %% [markdown]
# We can see, Indian Rupees is most used currecny. It means that zomato has main business in India followed by Dollar.

# %%
sns.countplot(x='Has Table booking',data=df)
# Out:
# <Axes: xlabel='Has Table booking', ylabel='count'>

# %% [markdown]
# We can see, Zomato has not provivded the table booking. But in some place it provided table booking. May be their zomaato own its Restaurant.

# %%
sns.countplot(x='Has Online delivery',data=df)
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='count'>

# %% [markdown]
# Most of places has no online delivery available.

# %%
# Countries which do have online deliveries option
a=df[df['Has Online delivery']=='Yes'].Country.value_counts()

# %%
a.plot.pie(autopct = '%1.1f%%')
plt.title('Country has online delivery')
plt.show()

# %% [markdown]
# We can see, India has 98.9% online delivery available but UAE has only 1.1% online delivery.

# %%
sns.countplot(x='Is delivering now',data=df)
# Out:
# <Axes: xlabel='Is delivering now', ylabel='count'>

# %% [markdown]
# Most of the places has not availavel delivery Now system.

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Aggregate rating',data=df)
plt.show()

# %% [markdown]
# Most of the coustomer has gives 0 aggregate rating than others.

# %%
sns.countplot(x='Rating color',data=df)
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %% [markdown]
# Red color are less used for rating. It means no one dislike the food delivered by zomato.

# %%
sns.countplot(x='Rating text',data=df)
# Out:
# <Axes: xlabel='Rating text', ylabel='count'>

# %% [markdown]
# In rating text, Average is the most used test followed by good.
# But some of customer are not rated the zomato service.

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Country',data=df)
plt.show()

# %% [markdown]
# We can obsere before that Indian currency is most used. It because of in India is the most of Zomato businees do followed by USA.

# %%
city_values = df.City.value_counts().values
city_labels = df.City.value_counts().index

# %%
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# 68.7% zomato works in New Delhi foolowed by Gurgaon.

# %%
# Top 10 Cuisines are
cuisin_val=df.Cuisines.value_counts().values
cuisin_label = df.Cuisines.value_counts().index

# %%
plt.pie(cuisin_val[:10],labels=cuisin_label[:10],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# We can see, 26.58% people or customers like to eat north Indian cuisine followed by Chinese.

# %%
# Find top 10 location
val=df.Locality.value_counts().values
label = df.Locality.value_counts().index

# %%
plt.pie(val[:10],labels=label[:10],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# These are the top 10 place where most of zomato restaurants are located.

# %%
plt.figure(figsize=(15,6))
df_good = df.sort_values(by="Average Cost for two",ascending=False)
sns.barplot(x="Country",y="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# We can see, Indonesia has high Average cost for two. It means that Indonesia has high cost of foos than others.

# %%
plt.figure(figsize=(20,6))
df_good = df.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(x="Restaurant Name",y="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# These are the top 10 restaurant name where average cost for two is low than others.

# %%
df_good = df.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(y="City",x="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# These are top cities where has high average cost for two in which Jakartha is in to followed bt Tangerang.

# %%
sns.barplot(x='Has Online delivery',y='Votes',data=df)
plt.title('Has Online delivery VS Votes')
plt.show()

# %% [markdown]
# Yes,you can observe that median number of votes for both categories vary.
# Restaurants accepting online orders tend to get more votes from customers as there is a rating option poping up after each order through zomato application.

# %%
df.groupby('Restaurant Name')['Aggregate rating'].mean().nlargest(10).plot.bar()
plt.show()

# %% [markdown]
# These are the top 10 restaurant name where most of the coustomers gives good aggregate rating.

# %%
sns.barplot(x='Has Online delivery',y='Average Cost for two',data=df)
plt.title('Has Online delivery VS Average Cost for two')
plt.show()

# %% [markdown]
# Average cost for two has not affected by online delivery system.

# %%
df.groupby('Restaurant Name')['Votes'].mean().nlargest(10).plot.bar()
plt.show()

# %% [markdown]
# We can see, top 10 reaturant on basis of the customers votes.

# %%
sns.scatterplot(x='Average Cost for two',y='Longitude',data=df)
# Out:
# <Axes: xlabel='Average Cost for two', ylabel='Longitude'>

# %% [markdown]
# It does not have any linear correlation of both features.

# %%
sns.scatterplot(x='Average Cost for two',y='Latitude',data=df)
# Out:
# <Axes: xlabel='Average Cost for two', ylabel='Latitude'>

# %% [markdown]
# We can see, both feature is not have nay linear relationship with each others.

# %%
rating=df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating count'})

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating count',data=rating)
plt.show()

# %%
plt.figure(figsize=(10,6))
df_good = df.sort_values(by="Latitude",ascending=False).iloc[0:10,:]
sns.barplot(y="Restaurant Name",x="Latitude",data=df_good)
plt.show()

# %% [markdown]
# We can see, by latitude The Kitchen has highest latitude. It mean at high latitude criteria, it is top.

# %%
sns.barplot(x='Price range',y='Average Cost for two',data=df)
# Out:
# <Axes: xlabel='Price range', ylabel='Average Cost for two'>

# %% [markdown]
# Many restaurant are having as price range 3 it means that those are also having high average price range.

# %%
sns.barplot(x='Rating text',y='Average Cost for two',data=df)
# Out:
# <Axes: xlabel='Rating text', ylabel='Average Cost for two'>

# %% [markdown]
# Whose having as rating text Excellent those restaurant are having high average cost for two.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating text',data=rating)
plt.show()

# %% [markdown]
# We can see, Many restaurant are having Excellent as rating text and their Aggrege=ate rating also high it mean more than 4.5.

# %%
Delhi = df[(df.City == 'New Delhi')]
top_locality = Delhi.Locality.value_counts().head(10)
plt.figure(figsize=(12,6))
sns.countplot(y= "Locality", hue="Has Online delivery", data=Delhi[Delhi.Locality.isin(top_locality.index)])
plt.title('Resturants Online Delivery')
plt.show()

# %% [markdown]
# We can see, most of the place has no online delivery option. or online order system.
# But Malviya Nagar is top among the restaurant whose having online ordered or online delivery.

# %%
sns.countplot(x='Has Online delivery',hue='Has Table booking',data=df)
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='count'>

# %% [markdown]
# We can see, those are not providing online delivery they also have less table booking but it doe not have any impact on business because most of the restaurant has not provided online delivery.

# %%
sns.countplot(x='Rating color',hue='Price range',data=df)
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %% [markdown]
# As per price range the rating color has change. In Which the Orange rating color has more count than others.

# %%
sns.scatterplot(x='Votes',y='Average Cost for two',data=df)
# Out:
# <Axes: xlabel='Votes', ylabel='Average Cost for two'>

# %% [markdown]
# Votes has no linear relationship with Average cost for two.

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',data=df)
# Out:
# <Axes: xlabel='Votes', ylabel='Aggregate rating'>

# %% [markdown]
# There is no direct linear relationship with each others.

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='Aggregate rating',y='Average Cost for two',hue='Has Online delivery',data=df)
plt.show()

# %% [markdown]
# We can see, very few restaurant has accepted the online delivery it mean online oders.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating count',hue='Rating color',data=rating)
plt.show()

# %% [markdown]
# Not Rated count is very high.
# Maximum number of rating are between 2.5 to 3.4.

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="Average Cost for two", y="Aggregate rating", hue='Price range', data=Delhi)

plt.xlabel("Average Cost for two")
plt.ylabel("Aggregate rating")
plt.title('Rating vs Cost of Two')
plt.show()

# %% [markdown]
# We can observe there is no linear relation between price and rating. For instance, Restaurants with good rating (like 4–5) have restaurants with all the price range and spread across the entire X axis

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',hue='Has Online delivery',data=df)
# Out:
# <Axes: xlabel='Votes', ylabel='Aggregate rating'>

# %% [markdown]
# We can see, many restaurant are having more than 4 rating and they also have online delivery.

# %%
df.drop(columns=['Restaurant ID','Locality Verbose'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for col in df[df.columns[df.dtypes == 'object']]:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Restaurant Name  Country Code  City  Address  Locality   Longitude  \
# 0             3749           162    73     8685       171  121.027535
# 1             3173           162    73     6055       593  121.014101
# 2             2897           162    75     4684       308  121.056831
# 3             4707           162    75     8690       862  121.056475
# 4             5523           162    75     8689       862  121.057508
#
#     Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0  14.565443       920                  1100         0                  1
# 1  14.553708      1111                  1200         0                  1
# 2  14.581404      1671                  4000         0                  1
# 3  14.585318      1126                  1500         0                  0
# 4  14.584450      1122                  1500         0                  1
#
#    Has Online delivery  Is delivering now  Switch to order menu  Price range  \
# ...

# %%
df.describe()
# Out:
#        Restaurant Name  Country Code         City      Address     Locality  \
# count      9551.000000   9551.000000  9551.000000  9551.000000  9551.000000
# mean       3653.204586     18.365616    78.301434  4542.439430   658.128468
# std        2142.917876     56.750546    23.198915  2565.717005   315.866515
# min           0.000000      1.000000     0.000000     0.000000     0.000000
# 25%        1777.500000      1.000000    76.000000  2323.500000   381.000000
# 50%        3595.000000      1.000000    88.000000  4610.000000   696.000000
# 75%        5485.500000      1.000000    88.000000  6746.500000   921.000000
# max        7445.000000    216.000000   140.000000  8917.000000  1207.000000
#
#          Longitude     Latitude    Cuisines  Average Cost for two  \
# count  9551.000000  9551.000000  9551.00000           9551.000000
# mean     64.126574    25.854381   989.95079           1199.210763
# std      41.467058    11.007935   514.72354          16121.183073
# ...

# %% [markdown]
# 1. Difference between 75% and max in Average Cost for two, Evaporation and Votes is high, columns is considerable indicating presence of outliers.
#
# 2. In some features Mean to Standrad of deviation difference is close.

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
# Correlation between feature column and lable column

plt.figure(figsize = (20,8))
df.corr()['Average Cost for two'].sort_values(ascending = False).drop(['Average Cost for two']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Average Cost for two',fontsize=15)
plt.title('correlation',fontsize = 18)
plt.show()

# %%
df.shape
# Out:
# (9551, 20)

# %%
plt.figure(figsize=(25,30))
plotnumber = 1
for column in df:
    if plotnumber <=20:
        ax = plt.subplot(4,5,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# All features are having some skewness.

# %%
df.skew()
# Out:
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %%
# Checking for outliers

plt.figure(figsize=(25,30))
plotnumber = 1

for column in df:
    if plotnumber <=20:
        plt.subplot(5,4,plotnumber)
        ax = sns.boxplot(data=df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %%
from scipy.stats import zscore

z_score = zscore(df[['Average Cost for two','Votes']]) # Only removing outliers from continuous data
abs_z_score = np.abs(z_score)    # Apply the formula and get the scaled data

filtering_entry = (abs_z_score  < 3).all(axis=1)

df5 = df[filtering_entry]

# %%
df5.shape
# Out:
# (9362, 20)

# %%
df.shape
# Out:
# (9551, 20)

# %%
# Data percentage loss

data_loss = ((9551 - 9362)/9551*100)
print(data_loss,'%')
# Out:
# 1.978850382158936 %

# %% [markdown]
# Since data lost is less than 10%, we are proceeding

# %%
# Dividing into Feature and Target data

x = df5.drop(columns=['Average Cost for two'],axis=1)
y = df5['Average Cost for two']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaled_X = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()

# %%
vif["Features"] = x.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]
vif
# Out:
#                 Features        vif
# 0        Restaurant Name   1.008700
# 1           Country Code  48.278786
# 2                   City   1.081831
# 3                Address   1.106130
# 4               Locality   1.068078
# 5              Longitude   5.031289
# 6               Latitude   3.037873
# 7               Cuisines   1.043922
# 8               Currency   1.294013
# 9      Has Table booking   1.482431
# 10   Has Online delivery   1.168622
# 11     Is delivering now   1.014266
# 12  Switch to order menu        NaN
# 13           Price range   1.949610
# 14      Aggregate rating   1.947962
# 15          Rating color   1.221294
# 16           Rating text   1.426143
# 17                 Votes   1.613811
# 18               Country  66.489679

# %% [markdown]
# If VIF > 10, It means multicollinearity is present.
# MultiCollinearity exists in Country Code, Switch to order menu and Country Based on ANOVA F scores.

# %%
# Dropping columns who are having multicollinearity

df5.drop(columns=['Country Code','Switch to order menu','Country'],axis=1,inplace=True)

# %%
df5.shape
# Out:
# (9362, 17)

# %%
x = df5.drop(columns=['Average Cost for two'],axis=1)
y = df5['Average Cost for two']

# %%
# Removing skewness from the data

from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %%
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[ 0.15320122, -0.40644576,  1.47370479, ..., -2.26885617,
#         -0.20420612,  1.30223393],
#        [-0.10300615, -0.40644576,  0.61835876, ..., -2.26885617,
#         -0.20420612,  1.65627302],
#        [-0.23099771, -0.310708  ,  0.13463254, ..., -1.38742706,
#          1.51689551,  1.21890769],
#        ...,
#        [-0.15079956,  3.88657629,  0.58789144, ...,  1.32393817,
#          0.39794913,  1.71976831],
#        [-1.61804193,  3.88657629,  0.58823442, ..., -1.38742706,
#          1.51689551,  1.8967675 ],
#        [ 1.50177812,  3.88657629, -0.0228778 , ..., -1.38742706,
#          1.51689551,  1.65627302]])

# %% [markdown]
# # Finding Best Random State

# %%
#Finding the best random state

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_val_score, train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
maxAccu=0
maxRS=0
for i in range(1,50):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state= i)
    le=LinearRegression()
    le.fit(x_train,y_train)
    pred=le.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print('Best Accuracy is ',maxAccu,'at random state ',maxRS)
# Out:
# Best Accuracy is  0.5797431387221117 at random state  16

# %% [markdown]
# # Training & Testing of Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=16)

# %%
# Using Linear Regression

from sklearn.linear_model import LinearRegression

lg=LinearRegression()
lg.fit(x_train,y_train)
predlg=lg.predict(x_test)
print("r2 accuracy score is: ",r2_score(y_test,predlg))

for i in range(2,15):
    cvs = cross_val_score(lg,x, y,cv =i) 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())
    
print('\n Mean absolute error:',mean_absolute_error(y_test,predlg))
print('\n Mean squared error:',mean_squared_error(y_test,predlg))
print('\n Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predlg)))
# Out:
# r2 accuracy score is:  0.549328479250434
# Cross Validation Score for cv= 2 is 0.23903822438786726
# Cross Validation Score for cv= 3 is 0.19409565681813848
# Cross Validation Score for cv= 4 is 0.24184874749264265
# Cross Validation Score for cv= 5 is 0.04201664318335361
# Cross Validation Score for cv= 6 is 0.08451203793521307
# Cross Validation Score for cv= 7 is 0.031096701411556942
# Cross Validation Score for cv= 8 is -0.003940894385640575
# Cross Validation Score for cv= 9 is -0.05676809700976832
# Cross Validation Score for cv= 10 is 0.01241588535532374
# Cross Validation Score for cv= 11 is 0.043192606602712805
# Cross Validation Score for cv= 12 is 0.05748634779140357
# Cross Validation Score for cv= 13 is 0.03619087196577826
# Cross Validation Score for cv= 14 is 0.018791002491372603
#
#  Mean absolute error: 217.2632690506713
#
#  Mean squared error: 153700.87585508052
#
#  Root Mean squared error: 392.0470327079144

# %%
# Using Random Forest Regression

from sklearn.ensemble import RandomForestRegressor
RF=RandomForestRegressor()
RF.fit(x_train,y_train)
predRF=RF.predict(x_test)
print("r2 accuracy score is: ",r2_score(y_test,predRF))

for i in range(2,10):
    cvs = cross_val_score(RF,x, y,cv =i) 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())
    
print('\n Mean absolute error:',mean_absolute_error(y_test,predRF))
print('\n Mean squared error:',mean_squared_error(y_test,predRF))
print('\n Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predRF)))
# Out:
# r2 accuracy score is:  0.8811850831371641
# Cross Validation Score for cv= 2 is 0.5657983722633313
# Cross Validation Score for cv= 3 is 0.5386731613291489
# Cross Validation Score for cv= 4 is 0.6102541857848531
# Cross Validation Score for cv= 5 is 0.4403290303082311
# Cross Validation Score for cv= 6 is 0.47960930163421783
# Cross Validation Score for cv= 7 is 0.443053882227887
# Cross Validation Score for cv= 8 is 0.3973469041756052
# Cross Validation Score for cv= 9 is 0.39353197350560104
#
#  Mean absolute error: 103.13211819152723
#
#  Mean squared error: 40521.65700662157
#
#  Root Mean squared error: 201.29991804921724

# %%
# Using XGB Regression

from xgboost import XGBRegressor
xb=XGBRegressor()
xb.fit(x_train,y_train)
predxb=xb.predict(x_test)
print("r2 accuracy score is: ",r2_score(y_test,predxb))

for i in range(2,8):
    cvs = cross_val_score(xb,x, y,cv =i) 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())
    
print('\n Mean absolute error:',mean_absolute_error(y_test,predxb))
print('\n Mean squared error:',mean_squared_error(y_test,predxb))
print('\n Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predxb)))
# Out:
# r2 accuracy score is:  0.8706387670529814
# Cross Validation Score for cv= 2 is 0.5718146273264206
# Cross Validation Score for cv= 3 is 0.5723544249044633
# Cross Validation Score for cv= 4 is 0.6148107220092006
# Cross Validation Score for cv= 5 is 0.4959695976593556
# Cross Validation Score for cv= 6 is 0.5245770906466874
# Cross Validation Score for cv= 7 is 0.49300673627807756
#
#  Mean absolute error: 108.4306125543261
#
#  Mean squared error: 44118.46298292861
#
#  Root Mean squared error: 210.04395488308776

# %%
# Using Decision Tree Regressor

from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
preddt=dt.predict(x_test)
print("r2 accuracy score is: ",r2_score(y_test,preddt))

for i in range(2,10):
    cvs = cross_val_score(dt,x, y,cv =i) 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())
    
print('\n Mean absolute error:',mean_absolute_error(y_test,preddt))
print('\n Mean squared error:',mean_squared_error(y_test,preddt))
print('\n Root Mean squared error:',np.sqrt(mean_squared_error(y_test,preddt)))
# Out:
# r2 accuracy score is:  0.8133367557716429
# Cross Validation Score for cv= 2 is 0.3724130404014004
# Cross Validation Score for cv= 3 is 0.30595906935358125
# Cross Validation Score for cv= 4 is 0.37893686801142007
# Cross Validation Score for cv= 5 is 0.2114737227978491
# Cross Validation Score for cv= 6 is 0.25035114454126006
# Cross Validation Score for cv= 7 is 0.21509298467185292
# Cross Validation Score for cv= 8 is 0.14599257872886723
# Cross Validation Score for cv= 9 is 0.14969046577656586
#
#  Mean absolute error: 128.90352438590244
#
#  Mean squared error: 63661.23175507298
#
#  Root Mean squared error: 252.3117749037349

# %%
# Using KNeighbors Regression

from sklearn.neighbors import KNeighborsRegressor
KNR=KNeighborsRegressor()
KNR.fit(x_train,y_train)
predKNR=KNR.predict(x_test)
print("r2 accuracy score is: ",r2_score(y_test,predKNR))

for i in range(2,8):
    cvs = cross_val_score(KNR,x, y,cv =i) 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())
    
print('\n Mean absolute error:',mean_absolute_error(y_test,predKNR))
print('\n Mean squared error:',mean_squared_error(y_test,predKNR))
print('\n Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predKNR)))
# Out:
# r2 accuracy score is:  0.6727699661983613
# Cross Validation Score for cv= 2 is 0.42542427939769
# Cross Validation Score for cv= 3 is 0.40993255908010534
# Cross Validation Score for cv= 4 is 0.42919419260829206
# Cross Validation Score for cv= 5 is 0.33275888311295576
# Cross Validation Score for cv= 6 is 0.36972071996360983
# Cross Validation Score for cv= 7 is 0.3394216961276846
#
#  Mean absolute error: 165.12274830900677
#
#  Mean squared error: 111601.33375578497
#
#  Root Mean squared error: 334.06785801059186

# %%
# Using GradientBoost Regression

from sklearn.ensemble import GradientBoostingRegressor
BG=KNeighborsRegressor()
BG.fit(x_train,y_train)
predBG=BG.predict(x_test)
print("r2 accuracy score is: ",r2_score(y_test,predBG))

for i in range(2,8):
    cvs = cross_val_score(BG,x, y,cv =i) 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())
    
print('\n Mean absolute error:',mean_absolute_error(y_test,predBG))
print('\n Mean squared error:',mean_squared_error(y_test,predBG))
print('\n Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predBG)))
# Out:
# r2 accuracy score is:  0.6727699661983613
# Cross Validation Score for cv= 2 is 0.42542427939769
# Cross Validation Score for cv= 3 is 0.40993255908010534
# Cross Validation Score for cv= 4 is 0.42919419260829206
# Cross Validation Score for cv= 5 is 0.33275888311295576
# Cross Validation Score for cv= 6 is 0.36972071996360983
# Cross Validation Score for cv= 7 is 0.3394216961276846
#
#  Mean absolute error: 165.12274830900677
#
#  Mean squared error: 111601.33375578497
#
#  Root Mean squared error: 334.06785801059186

# %% [markdown]
# # Plot Actual VS Predicted Average Cost for two

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predRF)
plt.plot(y_test,y_test)
plt.xlabel('Actual Average Cost for two')
plt.ylabel('Predicted Average Cost for two')
plt.show()

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(RF,'Project_Average Cost for two.pkl')
# Out:
# ['Project_Average Cost for two.pkl']

# %% [markdown]
# # Predicting the saved model

# %%
model=joblib.load('Project_Average Cost for two.pkl')

#Prediction
prediction=model.predict(x_test)
prediction
# Out:
# array([ 211.2,  681.5, 2987. , ...,  298.5,  644.5,  128.5])

# %% [markdown]
# # 2. Predicting Price range

# %%
df.head()
# Out:
#    Restaurant Name  City  Address  Locality   Longitude   Latitude  Cuisines  \
# 0             3749    73     8685       171  121.027535  14.565443       920
# 1             3173    73     6055       593  121.014101  14.553708      1111
# 2             2897    75     4684       308  121.056831  14.581404      1671
# 3             4707    75     8690       862  121.056475  14.585318      1126
# 4             5523    75     8689       862  121.057508  14.584450      1122
#
#    Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0                  1100         0                  1                    0
# 1                  1200         0                  1                    0
# 2                  4000         0                  1                    0
# 3                  1500         0                  0                    0
# 4                  1500         0                  1                    0
#
# ...

# %%
x = df.drop(columns=['Price range'],axis=1)
y = df['Price range']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaled_X = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()

# %%
vif["Features"] = x.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]
vif
# Out:
#                 Features       vif
# 0        Restaurant Name  1.006616
# 1                   City  1.071466
# 2                Address  1.085591
# 3               Locality  1.068649
# 4              Longitude  1.352341
# 5               Latitude  1.065993
# 6               Cuisines  1.037950
# 7   Average Cost for two  1.025811
# 8               Currency  1.180257
# 9      Has Table booking  1.095100
# 10   Has Online delivery  1.147437
# 11     Is delivering now  1.013187
# 12      Aggregate rating  1.536727
# 13          Rating color  1.214508
# 14           Rating text  1.255581
# 15                 Votes  1.238945

# %% [markdown]
# If VIF > 10, It means multicollinearity is present.
# MultiCollinearity not exists Based on ANOVA F scores.

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler

# transform my dataset into standard normal distribution
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[ 0.15183741, -0.39838037,  1.47688602, ..., -2.21005957,
#         -0.22451093,  1.1918848 ],
#        [-0.10403496, -0.39838037,  0.62362517, ..., -2.21005957,
#         -0.22451093,  1.5077858 ],
#        [-0.23184479, -0.3030848 ,  0.14051006, ..., -1.34510712,
#          1.50322837,  1.11676465],
#        ...,
#        [-0.15176169,  3.86046089,  0.59320973, ...,  1.32362429,
#          0.37685986,  1.5638909 ],
#        [-1.61602691,  3.86046089,  0.59355214, ..., -1.34510712,
#          1.50322837,  1.719424  ],
#        [ 1.49915845,  3.86046089, -0.01690761, ..., -1.34510712,
#          1.50322837,  1.5077858 ]])

# %%
# Balancing the data

from imblearn.over_sampling import SMOTE as sm

smt_x,smt_y = sm().fit_resample(x,y)

# %%
smt_y.value_counts()
# Out:
# 3    4444
# 4    4444
# 2    4444
# 1    4444
# Name: Price range, dtype: int64

# %% [markdown]
# # Finding Best Random State

# %%
#Finding the best random state
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
maxAccu=0
maxRS=0
for i in range(1,150):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state= i)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print('Best Accuracy is ',maxAccu,'at random state ',maxRS)
# Out:
# Best Accuracy is  0.7627355198883461 at random state  38

# %% [markdown]
# # Training & Testing of Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=38)

# %% [markdown]
# # Applying various models

# %%
# Using Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix, roc_auc_score,precision_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_val_score, train_test_split

lg=LogisticRegression()
lg.fit(x_train,y_train)
predlg=lg.predict(x_test)
print('Accuracy score is: ',accuracy_score(y_test,predlg),'%')

for i in range(2,10):
    cvs = cross_val_score(lg,x, y,cv =i,scoring='accuracy') 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())

print('\n Confusion Matrix: \n',confusion_matrix(y_test,predlg))
print('\n Classification Report: \n',classification_report(y_test,predlg))
# Out:
# Accuracy score is:  0.7627355198883461 %
# Cross Validation Score for cv= 2 is 0.8148943451989441
# Cross Validation Score for cv= 3 is 0.7727025929732441
# Cross Validation Score for cv= 4 is 0.7581478471817262
# Cross Validation Score for cv= 5 is 0.7410802162185857
# Cross Validation Score for cv= 6 is 0.7298771249922354
# Cross Validation Score for cv= 7 is 0.7254932471522333
# Cross Validation Score for cv= 8 is 0.725263734851963
# Cross Validation Score for cv= 9 is 0.7224548414077533
#
#  Confusion Matrix:
#  [[1246   95    4    0]
#  [ 189  664   78    5]
#  [  32  119  236   26]
#  [  17   32   83   40]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.84      0.93      0.88      1345
#            2       0.73      0.71      0.72       936
#            3       0.59      0.57      0.58       413
#            4       0.56      0.23      0.33       172
#
#     accuracy                           0.76      2866
# ...

# %%
# Using SVC model:

from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print('Accuracy score is: ',accuracy_score(y_test,predsvc),'%')

for i in range(2,10):
    cvs = cross_val_score(svc,x, y,cv =i,scoring='accuracy') 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())

print('\n Confusion Matrix: \n',confusion_matrix(y_test,predsvc))
print('\n Classification Report: \n',classification_report(y_test,predsvc))
# Out:
# Accuracy score is:  0.895324494068388 %
# Cross Validation Score for cv= 2 is 0.7923790198812561
# Cross Validation Score for cv= 3 is 0.8131125835481733
# Cross Validation Score for cv= 4 is 0.8226381435876492
# Cross Validation Score for cv= 5 is 0.8245443711113121
# Cross Validation Score for cv= 6 is 0.8274490380879888
# Cross Validation Score for cv= 7 is 0.8209884585460622
# Cross Validation Score for cv= 8 is 0.8212664151997765
# Cross Validation Score for cv= 9 is 0.8207944788294848
#
#  Confusion Matrix:
#  [[1306   38    0    1]
#  [  19  866   48    3]
#  [   8   77  309   19]
#  [   1    6   80   85]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.98      0.97      0.97      1345
#            2       0.88      0.93      0.90       936
#            3       0.71      0.75      0.73       413
#            4       0.79      0.49      0.61       172
#
#     accuracy                           0.90      2866
# ...

# %%
# Using KNN model:

from sklearn.neighbors import KNeighborsClassifier
kn=KNeighborsClassifier()
kn.fit(x_train,y_train)
predkn=kn.predict(x_test)
print('Accuracy score is: ',accuracy_score(y_test,predkn),'%')

for i in range(2,10):
    cvs = cross_val_score(kn,x, y,cv =i,scoring='accuracy') 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())

print('\n Confusion Matrix: \n',confusion_matrix(y_test,predkn))
print('\n Classification Report: \n',classification_report(y_test,predkn))
# Out:
# Accuracy score is:  0.7191207257501745 %
# Cross Validation Score for cv= 2 is 0.6167944872705587
# Cross Validation Score for cv= 3 is 0.6350165057142451
# Cross Validation Score for cv= 4 is 0.6293608455628232
# Cross Validation Score for cv= 5 is 0.6132542650568081
# Cross Validation Score for cv= 6 is 0.6000458504548724
# Cross Validation Score for cv= 7 is 0.6126395877547951
# Cross Validation Score for cv= 8 is 0.6205631749134046
# Cross Validation Score for cv= 9 is 0.6145302877279426
#
#  Confusion Matrix:
#  [[1167  174    4    0]
#  [ 262  593   78    3]
#  [  13  144  232   24]
#  [   2   25   76   69]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.81      0.87      0.84      1345
#            2       0.63      0.63      0.63       936
#            3       0.59      0.56      0.58       413
#            4       0.72      0.40      0.51       172
#
#     accuracy                           0.72      2866
# ...

# %%
# Using Decision Tree model:

from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
preddtc=dtc.predict(x_test)
print('Accuracy score is: ',accuracy_score(y_test,preddtc),'%')

for i in range(2,10):
    cvs = cross_val_score(dtc,x, y,cv =i,scoring='accuracy') 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())

print('\n Confusion Matrix: \n',confusion_matrix(y_test,preddtc))
print('\n Classification Report: \n',classification_report(y_test,preddtc))
# Out:
# Accuracy score is:  0.9741800418702024 %
# Cross Validation Score for cv= 2 is 0.8966639041630491
# Cross Validation Score for cv= 3 is 0.8309152317246511
# Cross Validation Score for cv= 4 is 0.8367742040744148
# Cross Validation Score for cv= 4 is 0.8367742040744148
# Cross Validation Score for cv= 5 is 0.8280251286982775
# Cross Validation Score for cv= 6 is 0.8801082986691261
# Cross Validation Score for cv= 7 is 0.8705131274255697
# Cross Validation Score for cv= 8 is 0.8811525846612217
# Cross Validation Score for cv= 9 is 0.8835149814052565
#
#  Confusion Matrix:
#  [[1336    9    0    0]
#  [   7  915   12    2]
#  [   0   13  391    9]
#  [   0    4   18  150]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      1345
#            2       0.97      0.98      0.97       936
#            3       0.93      0.95      0.94       413
#            4       0.93      0.87      0.90       172
#
# ...

# %%
# Using Random Forest classifier:

from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(x_train,y_train)
predRF=RF.predict(x_test)
print('Accuracy score is: ',accuracy_score(y_test,predRF),'%')

for i in range(2,10):
    cvs = cross_val_score(RF,x, y,cv =i,scoring='accuracy') 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())

print('\n Confusion Matrix: \n',confusion_matrix(y_test,predRF))
print('\n Classification Report: \n',classification_report(y_test,predRF))
# Out:
# Accuracy score is:  0.9665038381018841 %
# Cross Validation Score for cv= 2 is 0.9084943039806361
# Cross Validation Score for cv= 3 is 0.8871343180453529
# Cross Validation Score for cv= 4 is 0.8632609791732015
# Cross Validation Score for cv= 5 is 0.8443531935528943
# Cross Validation Score for cv= 6 is 0.9038743371161274
# Cross Validation Score for cv= 7 is 0.900657637293582
# Cross Validation Score for cv= 8 is 0.88722680530341
# Cross Validation Score for cv= 9 is 0.8979542330873821
#
#  Confusion Matrix:
#  [[1337    7    1    0]
#  [  11  919    6    0]
#  [   2   25  378    8]
#  [   0    2   34  136]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      1345
#            2       0.96      0.98      0.97       936
#            3       0.90      0.92      0.91       413
#            4       0.94      0.79      0.86       172
#
#     accuracy                           0.97      2866
# ...

# %%
# Using AdaBoost classifier:

from sklearn.ensemble import AdaBoostClassifier
Ad=AdaBoostClassifier()
Ad.fit(x_train,y_train)
predAd=Ad.predict(x_test)
print('Accuracy score is: ',accuracy_score(y_test,predAd),'%')

for i in range(2,10):
    cvs = cross_val_score(Ad,x, y,cv =i,scoring='accuracy') 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())

print('\n Confusion Matrix: \n',confusion_matrix(y_test,predAd))
print('\n Classification Report: \n',classification_report(y_test,predAd))
# Out:
# Accuracy score is:  0.8283321702721563 %
# Cross Validation Score for cv= 2 is 0.7803413007445605
# Cross Validation Score for cv= 3 is 0.7878770028275213
# Cross Validation Score for cv= 4 is 0.7905974854021539
# Cross Validation Score for cv= 5 is 0.7942750293834812
# Cross Validation Score for cv= 6 is 0.8294366368822953
# Cross Validation Score for cv= 7 is 0.8054721008638059
# Cross Validation Score for cv= 8 is 0.8303802471423898
# Cross Validation Score for cv= 9 is 0.8219073826564894
#
#  Confusion Matrix:
#  [[1304   41    0    0]
#  [  18  898   18    2]
#  [   0  341   40   32]
#  [   0   27   13  132]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98      1345
#            2       0.69      0.96      0.80       936
#            3       0.56      0.10      0.17       413
#            4       0.80      0.77      0.78       172
#
#     accuracy                           0.83      2866
# ...

# %%
# Using GuasianNB classifier:

from sklearn.naive_bayes import GaussianNB
Gu=GaussianNB()
Gu.fit(x_train,y_train)
predGu=Gu.predict(x_test)
print('Accuracy score is: ',accuracy_score(y_test,predGu),'%')

for i in range(2,10):
    cvs = cross_val_score(Gu,x, y,cv =i,scoring='accuracy') 
    print('Cross Validation Score for cv=',i,'is', cvs.mean())

print('\n Confusion Matrix: \n',confusion_matrix(y_test,predGu))
print('\n Classification Report: \n',classification_report(y_test,predGu))
# Out:
# Accuracy score is:  0.5083740404745289 %
# Cross Validation Score for cv= 2 is 0.41011688021258125
# Cross Validation Score for cv= 3 is 0.3977617298977872
# Cross Validation Score for cv= 4 is 0.4092792811284463
# Cross Validation Score for cv= 5 is 0.41035136890035917
# Cross Validation Score for cv= 6 is 0.398915210348832
# Cross Validation Score for cv= 7 is 0.4300267321004648
# Cross Validation Score for cv= 8 is 0.4318947349207619
# Cross Validation Score for cv= 9 is 0.4364215970791156
#
#  Confusion Matrix:
#  [[1289    2    0   54]
#  [ 742    6    0  188]
#  [  75    0    0  338]
#  [  10    0    0  162]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.61      0.96      0.74      1345
#            2       0.75      0.01      0.01       936
#            3       0.00      0.00      0.00       413
#            4       0.22      0.94      0.35       172
#
#     accuracy                           0.51      2866
# ...

# %% [markdown]
# # After several model performances, Random Forest Classifier has the best accuracy score of 96.65 % with CV score of 90.84%

# %% [markdown]
# # AUC ROC Curve:

# %%
from sklearn.metrics import roc_curve, auc
#predicting the data
y_pred_cnb = RF.predict(x_test)
y_prob_pred_cnb = RF.predict_proba(x_test)

# %%
# roc curve for classes
fpr = {}
tpr = {}
thresh ={}

n_class = 4

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, y_prob_pred_cnb[:,i], pos_label=i)
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--', label='Class 1 vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--', label='Class 2 vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--', label='Class 3 vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--', label='Class 4 vs Rest')


plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(RF,'Project_Price_Range.pkl')
# Out:
# ['Project_Price_Range.pkl']

# %% [markdown]
# # Predicting the saved model

# %%
model=joblib.load('Project_Price_Range.pkl')

#Prediction
prediction=model.predict(x_test)
prediction
# Out:
# array([2, 1, 2, ..., 1, 4, 1], dtype=int64)
