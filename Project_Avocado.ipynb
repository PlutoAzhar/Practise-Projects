# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Dataset:
df=pd.read_csv('C:/Users/Azhar1/Documents/FlipRobo/Project_Evaluation/Project_Phase 1/Avocado.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#    index        Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      0  12/27/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1      1  12/20/2015          1.35      54876.98   674.28   44638.81   58.33
# 2      2  12/13/2015          0.93     118220.22   794.70  109149.67  130.50
# 3      3  12-06-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4      4  11/29/2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# The dimension of our data is 18250 rows * 14 columns. Index column is not required, hence removing it.

# %%
df.drop('index', axis=1, inplace = True)

# %%
df.shape
# Out:
# (18249, 13)

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# We can see that Date column is in object format, we will change it in date format.

# %%
# Splitting date column between days and month
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  12/27/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  12/20/2015          1.35      54876.98   674.28   44638.81   58.33
# 2  12/13/2015          0.93     118220.22   794.70  109149.67  130.50
# 3  12-06-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  11/29/2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# 1. 75% is higher than max in 4770 and in small bags column.
# 2. mean is higer than max in Total volume and 4770 and total bags column.

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# There are no null values in our dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.093197
# ...

# %% [markdown]
# # Feature Engineering

# %%
# Converting object data types 
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['type']=le.fit_transform(df['type'])
df['region']=le.fit_transform(df['region'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  datetime64[ns]
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  int32
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  int32
#  13  Month         18249 non-null  int64
#  14  Day           18249 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int32(2), int64(3)
# memory usage: 1.9 MB

# %% [markdown]
# We can see that all the data type is now converted to integers and float (except date).

# %%
# As data column is not relevant to our present analysis, removing it.
df.drop('Date', axis=1, inplace = True)

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Month  Day
# 0     8603.62       93.25          0.0     0  2015       0     12   27
# 1     9408.07       97.49          0.0     0  2015       0     12   20
# 2     8042.21      103.14          0.0     0  2015       0     12   13
# 3     5677.40      133.76          0.0     0  2015       0     12    6
# 4     5986.26      197.69          0.0     0  2015       0     11   29

# %% [markdown]
# # Data Visualization

# %%
sns.heatmap(df.isnull(),cmap='crest')
# Out:
# <Axes: >

# %% [markdown]
# No null values present graphically.

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidths=0.1,linecolor='black',annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
plt.figure(figsize=(20,20), facecolor = 'white')
plotnum = 1
for column in df:
    if plotnum<=20:
        ax = plt.subplot(5,4,plotnum)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnum+=1
plt.tight_layout()

# %%
sns.pairplot(df)

# %%
sns.countplot(df['type'])
plt.show()

# %%
df['type'].value_counts()
# Out:
# 0    9126
# 1    9123
# Name: type, dtype: int64

# %% [markdown]
# Our data is well balanced between Organic and conventional types.

# %%
df['region'].value_counts()
# Out:
# 0     338
# 40    338
# 29    338
# 30    338
# 31    338
# 32    338
# 33    338
# 34    338
# 35    338
# 36    338
# 37    338
# 38    338
# 39    338
# 41    338
# 1     338
# 42    338
# 43    338
# 44    338
# 45    338
# 46    338
# 47    338
# 48    338
# 49    338
# 50    338
# 51    338
# 52    338
# 28    338
# 27    338
# 26    338
# 25    338
# 2     338
# 3     338
# 4     338
# 5     338
# 6     338
# 7     338
# 8     338
# 9     338
# 10    338
# 11    338
# 12    338
# 13    338
# 14    338
# 15    338
# 16    338
# 17    338
# 18    338
# 19    338
# 20    338
# 21    338
# 22    338
# 23    338
# 24    338
# 53    335
# Name: region, dtype: int64

# %% [markdown]
# All regions are having equal number comparitively

# %%
sns.barplot(x = 'Month', y ='AveragePrice',data= df)
plt.show()

# %% [markdown]
# Graph showing Average price of Avocado from months Jan till Dec

# %%
sns.barplot(x = 'Month', y ='Total Volume',data= df)
# Out:
# <Axes: xlabel='Month', ylabel='Total Volume'>

# %% [markdown]
# Graph showing Volumes aganist Month.

# %%
sns.barplot(x = 'region', y ='AveragePrice', data = df)
# Out:
# <Axes: xlabel='region', ylabel='AveragePrice'>

# %% [markdown]
# Graph representing Average price aganist region

# %%
sns.barplot(x = 'year', y ='Total Volume', data = df)
# Out:
# <Axes: xlabel='year', ylabel='Total Volume'>

# %% [markdown]
# Graph representing volume sold to year. 2018 has the highest number of sales.

# %%
# Checking for Skewness
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# Month            0.106617
# Day              0.014310
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
df_new = power_transform(df)

# %%
df=pd.DataFrame(df_new, columns=df.columns)

# %%
df.skew()
# Out:
# AveragePrice    0.005596
# Total Volume    0.011171
# 4046           -0.022679
# 4225           -0.017740
# 4770            0.032184
# Total Bags     -0.001626
# Small Bags      0.007058
# Large Bags     -0.073809
# XLarge Bags     0.793520
# type            0.000329
# year            0.213156
# region         -0.261443
# Month          -0.146584
# Day            -0.208462
# dtype: float64

# %%
column=df.columns

# %%
#checking for outliers 
plt.figure(figsize=(20,30))
for i in range(14):
    plt.subplot(6,3,i+1) 
    sns.boxplot(y=df[column[i]],color='lightblue') 
    plt.tight_layout()

# %% [markdown]
# we can observe that there are few outliers present in our data.

# %%
from scipy.stats import probplot
plt.figure(figsize=(35,50))
for i in range(14):
    plt.subplot(5,4,i+1)
    probplot(df[column[i]],plot=plt,dist='norm')
    plt.title(column[i])
    plt.tight_layout()

# %%
# Using z-squre to remove outliers
from scipy.stats import zscore

z_score = zscore(df[['AveragePrice','Total Bags']])
abs_z_score = np.abs(z_score)

filtering_entry = (abs_z_score < 3).all(axis=1)

df= df[filtering_entry]

# %%
df.shape
# Out:
# (18189, 14)

# %%
#Checking Data loss percentage:
print ('Data lost % is = ', ((18249-18189)/18249)*100 , '%')
# Out:
# Data lost % is =  0.32878513891172123 %

# %% [markdown]
# We are proceeding further as data loss is only 0.328 %

# %% [markdown]
# # Task one: Proceeding with Average Price as Target

# %%
x = df.drop('AveragePrice', axis = 1 )
y = df['AveragePrice']

# %%
# Scaling data with Standard Scalaer
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[-0.08549265, -0.65820783,  0.31060215, ..., -2.01002507,
#          1.49269275,  1.22971549],
#        [-0.15486587, -0.77678108,  0.23468696, ..., -2.01002507,
#          1.49269275,  0.54136901],
#        [ 0.18133456, -0.73173553,  0.58369061, ..., -2.01002507,
#          1.49269275, -0.21527848],
#        ...,
#        [-0.77269873, -0.61931421, -0.7727697 , ...,  1.54801022,
#         -1.64225369,  0.64321542],
#        [-0.69902335, -0.5495752 , -0.71061226, ...,  1.54801022,
#         -1.64225369, -0.10165701],
#        [-0.66464015, -0.36670376, -0.7854884 , ...,  1.54801022,
#         -1.64225369, -0.95463382]])

# %%
x=x_scaled
x
# Out:
# array([[-0.08549265, -0.65820783,  0.31060215, ..., -2.01002507,
#          1.49269275,  1.22971549],
#        [-0.15486587, -0.77678108,  0.23468696, ..., -2.01002507,
#          1.49269275,  0.54136901],
#        [ 0.18133456, -0.73173553,  0.58369061, ..., -2.01002507,
#          1.49269275, -0.21527848],
#        ...,
#        [-0.77269873, -0.61931421, -0.7727697 , ...,  1.54801022,
#         -1.64225369,  0.64321542],
#        [-0.69902335, -0.5495752 , -0.71061226, ...,  1.54801022,
#         -1.64225369, -0.10165701],
#        [-0.66464015, -0.36670376, -0.7854884 , ...,  1.54801022,
#         -1.64225369, -0.95463382]])

# %% [markdown]
# # Finding Best Random State

# %%
#Finding the best random state
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
maxAccu=0
maxRS=0
for i in range(1,150):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state= i)
    le=LinearRegression()
    le.fit(x_train,y_train)
    pred=le.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print('Best Accuracy is ',maxAccu,'at random state ',maxRS)
# Out:
# Best Accuracy is  0.5906348908048031 at random state  20

# %% [markdown]
# # Training & Testing of Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=20)

# %%
# Using Logistic Regression

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
lg=LinearRegression()
lg.fit(x_train,y_train)
predlg=lg.predict(x_test)
print("r2 accuracy score is: ",r2_score(y_test,predlg))
print('Mean absolute error:',mean_absolute_error(y_test,predlg))
print('Mean squared error:',mean_squared_error(y_test,predlg))
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predlg)))
# Out:
# r2 accuracy score is:  0.5906348908048031
# Mean absolute error: 0.5154072409681582
# Mean squared error: 0.42313318701379776
# Root Mean squared error: 0.6504868845824624

# %%
# Checking with KNN model

from sklearn.neighbors import KNeighborsRegressor
KN = KNeighborsRegressor()
KN.fit(x_train,y_train)
predKN=KN.predict(x_test)
r2_sc = r2_score(y_test, predKN)
r2_sc
# Out:
# 0.8122049314666088

# %%
# Chacking for AdaBoostRegressor

from sklearn.ensemble import AdaBoostRegressor
AD =  AdaBoostRegressor()
AD.fit(x_train,y_train)
predAD=AD.predict(x_test)
r2_score = r2_score(y_test, predAD)
r2_score
# Out:
# 0.6092697389363722

# %%
# Checking for DecissionTreeRegressor

from sklearn.tree import DecisionTreeRegressor
DT =  DecisionTreeRegressor()
DT.fit(x_train,y_train)
predDT=DT.predict(x_test)
r2_score = r2_score(y_test, predDT)
r2_score
# Out:
# 0.7727387700270479

# %% [markdown]
# We can observe that KNN is a better model.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'algorithm': ['kd_tree', 'brute'], 
              'leaf_size' : [10,11,14,15,18,20,25],
              'n_neighbors': [3,5,7,9,11,13],
             }

# %%
gridsearch = GridSearchCV(estimator=KN, param_grid=param_grid)

# %%
gridsearch.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'algorithm': ['kd_tree', 'brute'],
#                          'leaf_size': [10, 11, 14, 15, 18, 20, 25],
#                          'n_neighbors': [3, 5, 7, 9, 11, 13]})

# %%
gridsearch.best_params_
# Out:
# {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 5}

# %%
KNN = KNeighborsRegressor(algorithm = 'kd_tree', leaf_size=10 , n_neighbors=5)

# %%
KNN.fit(x_train,y_train)
y_pred = KNN.predict(x_test)
r2_score = r2_score(y_test, y_pred)
r2_score
# Out:
# 0.8122049314666088

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(KNN,'Project_Avocado.pkl')
# Out:
# ['Project_Avocado.pkl']

# %% [markdown]
# # Second Task: Proceeding with Region as Target

# %%
x_new = df.drop(columns=['region'],axis=1)
y_new = df['region']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_new=le.fit_transform(y_new)

# %%
print(df['region'])
# Out:
# 0       -2.011552
# 1       -2.011552
# 2       -2.011552
# 3       -2.011552
# 4       -2.011552
#            ...
# 18244    1.543838
# 18245    1.543838
# 18246    1.543838
# 18247    1.543838
# 18248    1.543838
# Name: region, Length: 18189, dtype: float64

# %%
x_new
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0         -0.086248     -0.086605 -0.658619  0.307313 -0.247250   -0.524004
# 1         -0.034022     -0.155746 -0.776870  0.231647 -0.201041   -0.485890
# 2         -1.273938      0.179327 -0.731947  0.579503 -0.007072   -0.552018
# 3         -0.793421      0.003876 -0.634200  0.415100 -0.148322   -0.695449
# 4         -0.219440     -0.187640 -0.685293  0.224806 -0.137918   -0.669157
# ...             ...           ...       ...       ...       ...         ...
# 18244      0.640729     -0.674587 -0.467366 -0.919470 -1.238310   -0.334466
# 18245      0.816307     -0.767550 -0.619883 -0.665372 -1.238310   -0.496897
# 18246      1.147790     -0.771505 -0.619831 -0.772496  0.401546   -0.490952
# 18247      1.265876     -0.698077 -0.550282 -0.710543  0.401246   -0.424252
# 18248      0.618287     -0.663809 -0.367908 -0.785173  0.122919   -0.384961
#
# ...

# %%
y_new
# Out:
# array([ 0,  0,  0, ..., 53, 53, 53], dtype=int64)

# %% [markdown]
# # Finding Best Random State

# %%
#Finding the best random state
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu=0
maxRS=0
for i in range(1,10):
    x_new_train,x_new_test,y_new_train,y_new_test=train_test_split(x_new,y_new,test_size=0.30,random_state= i)
    RFR=RandomForestClassifier()
    RFR.fit(x_new_train,y_new_train)
    pred=RFR.predict(x_new_test)
    acc=accuracy_score(y_new_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print('Best Accuracy is ',maxAccu,'at random state ',maxRS)
# Out:
# Best Accuracy is  0.9129558365402236 at random state  8

# %% [markdown]
# # Training & Testing of Data

# %%
from sklearn.model_selection import train_test_split
x_new_train,x_new_test,y_new_train,y_new_test=train_test_split(x_new,y_new,test_size=0.3,random_state=8)

# %%
# Using Logistic Regression

from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
lg.fit(x_new_train,y_new_train)
predlg=lg.predict(x_new_test)
print(accuracy_score(y_new_test,predlg))
print(confusion_matrix(y_new_test,predlg))
print(classification_report(y_new_test,predlg))
# Out:
# 0.5437053326003298
# [[55  0  0 ...  0  0  0]
#  [ 0 41  0 ...  0  0  0]
#  [ 0  0 67 ...  0  0  7]
#  ...
#  [ 0  0  0 ... 86  1  0]
#  [ 0  0  0 ...  0 89  0]
#  [ 0  3  1 ...  0  0 24]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.64      0.66        86
#            1       0.24      0.48      0.32        86
#            2       0.74      0.60      0.66       112
#            3       0.61      0.42      0.50       107
#            4       0.50      0.52      0.51       109
#            5       0.56      0.48      0.52       101
#            6       0.80      0.94      0.87        96
#            7       0.57      0.74      0.64        99
#            8       0.71      0.81      0.76       110
#            9       0.55      0.77      0.64        96
#           10       0.61      0.45      0.52       108
#           11       0.60      0.62      0.61       110
#           12       0.53      0.45      0.48       112
# ...

# %%
# Using SVC model:

from sklearn.svm import SVC
svc=SVC(kernel='rbf')
svc.fit(x_new_train,y_new_train)
svc.score(x_new_train,y_new_train)
predsvc=svc.predict(x_new_test)
print(accuracy_score(y_new_test,predsvc))
print(confusion_matrix(y_new_test,predsvc))
print(classification_report(y_new_test,predsvc))
# Out:
# 0.7877954920285871
# [[ 81   0   0 ...   0   0   0]
#  [  0  47   0 ...   0   0   1]
#  [  0   0 106 ...   0   0   0]
#  ...
#  [  0   0   0 ...  87   0   0]
#  [  0   0   0 ...   0 108   0]
#  [  0   1   1 ...   0   0  61]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.94      0.78        86
#            1       0.41      0.55      0.47        86
#            2       0.95      0.95      0.95       112
#            3       0.82      0.70      0.76       107
#            4       0.90      0.87      0.88       109
#            5       0.85      0.68      0.76       101
#            6       1.00      0.98      0.99        96
#            7       0.76      0.77      0.76        99
#            8       0.97      0.97      0.97       110
#            9       0.73      0.77      0.75        96
#           10       0.56      0.60      0.58       108
#           11       0.86      0.82      0.84       110
# ...

# %%
svc=SVC(kernel='poly')
svc.fit(x_new_train,y_new_train)
svc.score(x_new_train,y_new_train)
predsvc=svc.predict(x_new_test)
print(accuracy_score(y_new_test,predsvc))
print(confusion_matrix(y_new_test,predsvc))
print(classification_report(y_new_test,predsvc))
# Out:
# 0.6611691405534176
# [[ 76   0   0 ...   0   0   0]
#  [  0  44   0 ...   0   0   0]
#  [  0   0  96 ...   0   0   0]
#  ...
#  [  0   0   0 ...  87   0   0]
#  [  0   0   0 ...   0 101   0]
#  [  0   5   2 ...   0   0  48]]
#               precision    recall  f1-score   support
#
#            0       0.58      0.88      0.70        86
#            1       0.29      0.51      0.37        86
#            2       0.91      0.86      0.88       112
#            3       0.81      0.65      0.73       107
#            4       0.84      0.72      0.78       109
#            5       0.73      0.55      0.63       101
#            6       0.90      0.78      0.84        96
#            7       0.68      0.40      0.51        99
#            8       0.97      0.95      0.96       110
#            9       0.61      0.75      0.67        96
#           10       0.52      0.40      0.45       108
#           11       0.86      0.81      0.84       110
# ...

# %%
# Using KNN model:
# k =10

from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_new_train,y_new_train)
knn.score(x_new_train,y_new_train)
predknn=knn.predict(x_new_test)
print(accuracy_score(y_new_test,predknn))
print(confusion_matrix(y_new_test,predknn))
print(classification_report(y_new_test,predknn))
# Out:
# 0.6389957852299798
# [[75  0  0 ...  0  0  0]
#  [ 0 48  0 ...  0  0  0]
#  [ 0  0 95 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 87  0  0]
#  [ 0  0  0 ...  1 93  0]
#  [ 0  4  3 ...  0  0 45]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.87      0.67        86
#            1       0.30      0.56      0.39        86
#            2       0.71      0.85      0.77       112
#            3       0.69      0.68      0.69       107
#            4       0.76      0.77      0.77       109
#            5       0.56      0.53      0.55       101
#            6       0.84      0.88      0.86        96
#            7       0.48      0.75      0.58        99
#            8       0.75      0.86      0.81       110
#            9       0.42      0.57      0.49        96
#           10       0.33      0.43      0.37       108
#           11       0.64      0.84      0.72       110
#           12       0.83      0.70      0.76       112
# ...

# %%
# Using Decision Tree model:

from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_new_train,y_new_train)
dtc.score(x_new_train,y_new_train)
preddtc=dtc.predict(x_new_test)
print(accuracy_score(y_new_test,preddtc))
print(confusion_matrix(y_new_test,preddtc))
print(classification_report(y_new_test,preddtc))
# Out:
# 0.7879787428990288
# [[ 72   0   0 ...   0   0   0]
#  [  0  67   0 ...   0   0   1]
#  [  0   0  98 ...   0   0   0]
#  ...
#  [  0   0   0 ...  86   0   0]
#  [  0   0   0 ...   0 104   0]
#  [  0   1   2 ...   0   0  54]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84        86
#            1       0.71      0.78      0.74        86
#            2       0.91      0.88      0.89       112
#            3       0.77      0.77      0.77       107
#            4       0.84      0.83      0.84       109
#            5       0.75      0.78      0.77       101
#            6       0.94      0.97      0.95        96
#            7       0.83      0.83      0.83        99
#            8       0.87      0.94      0.90       110
#            9       0.80      0.83      0.82        96
#           10       0.72      0.70      0.71       108
#           11       0.87      0.82      0.85       110
# ...

# %%
# Using Random Forest classifier:

from sklearn.ensemble import RandomForestClassifier
RF=DecisionTreeClassifier()
RF.fit(x_new_train,y_new_train)
RF.score(x_new_train,y_new_train)
preddtc=dtc.predict(x_new_test)
print(accuracy_score(y_new_test,preddtc))
print(confusion_matrix(y_new_test,preddtc))
print(classification_report(y_new_test,preddtc))
# Out:
# 0.7879787428990288
# [[ 72   0   0 ...   0   0   0]
#  [  0  67   0 ...   0   0   1]
#  [  0   0  98 ...   0   0   0]
#  ...
#  [  0   0   0 ...  86   0   0]
#  [  0   0   0 ...   0 104   0]
#  [  0   1   2 ...   0   0  54]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84        86
#            1       0.71      0.78      0.74        86
#            2       0.91      0.88      0.89       112
#            3       0.77      0.77      0.77       107
#            4       0.84      0.83      0.84       109
#            5       0.75      0.78      0.77       101
#            6       0.94      0.97      0.95        96
#            7       0.83      0.83      0.83        99
#            8       0.87      0.94      0.90       110
#            9       0.80      0.83      0.82        96
#           10       0.72      0.70      0.71       108
#           11       0.87      0.82      0.85       110
# ...

# %%
# Checking CV score for LG
score=cross_val_score(lg,x_new,y_new)
print(score)
print(score.mean())
# Out:
# [0.35871358 0.39692139 0.49147883 0.48625618 0.30134726]
# 0.40694344954723627

# %%
# Checking CV score for SVC
score=cross_val_score(svc,x_new,y_new)
print(score)
print(score.mean())
# Out:
# [0.38702584 0.47965915 0.54590434 0.48158329 0.32031894]
# 0.44289831330094476

# %%
# Checking CV score for KNN
score=cross_val_score(knn,x_new,y_new)
print(score)
print(score.mean())
# Out:
# [0.45519516 0.47773502 0.47141286 0.44117647 0.3582623 ]
# 0.440756364062897

# %%
# Checking CV score for DTC
score=cross_val_score(dtc,x_new,y_new)
print(score)
print(score.mean())
# Out:
# [0.49065421 0.67839472 0.63606377 0.54260583 0.41105307]
# 0.5517543184753004

# %%
# Checking CV score for RandomForest
score=cross_val_score(RF,x_new,y_new)
print(score)
print(score.mean())
# Out:
# [0.48982958 0.67454645 0.62781748 0.54425509 0.42452571]
# 0.5521948612263883

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

# %%
grids = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)

# %%
grids.fit(x_new_train,y_new_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.085 total time=  14.4s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.090 total time=  14.9s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.068 total time=  14.4s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.081 total time=  14.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.073 total time=  13.1s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.406 total time=  10.7s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.399 total time=  10.8s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.404 total time=  12.4s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.418 total time=  11.3s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.406 total time=  11.6s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.050 total time=  13.0s
# ...

# %%
print(grids.best_params_)
# Out:
# {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
print(grids.best_estimator_)
# Out:
# SVC(C=100, gamma=0.1)

# %%
grid_predictions = grids.predict(x_new_test)

# %%
print(accuracy_score(y_new_test,grid_predictions)*100)
print(confusion_matrix(y_new_test,grid_predictions))
print(classification_report(y_new_test,grid_predictions))
# Out:
# 90.63588052043248
# [[ 79   0   0 ...   0   0   0]
#  [  0  74   0 ...   0   0   0]
#  [  0   0 111 ...   0   0   0]
#  ...
#  [  0   0   0 ...  87   0   0]
#  [  0   0   0 ...   0 110   0]
#  [  0   1   0 ...   0   0  73]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87        86
#            1       0.80      0.86      0.83        86
#            2       0.98      0.99      0.99       112
#            3       0.86      0.92      0.89       107
#            4       0.97      0.95      0.96       109
#            5       0.92      0.83      0.87       101
#            6       1.00      0.98      0.99        96
#            7       0.90      0.95      0.93        99
#            8       0.97      0.97      0.97       110
#            9       0.88      0.89      0.88        96
#           10       0.83      0.89      0.86       108
#           11       0.94      0.93      0.94       110
# ...

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(grids.best_estimator_,'Project_Avocado1.pkl')
# Out:
# ['Project_Avocado1.pkl']

# %% [markdown]
# # Predicting the saved model

# %%
model=joblib.load('Project_Avocado1.pkl')

#Prediction
prediction=model.predict(x_test)
prediction
# Out:
# array([49, 52, 51, ..., 49, 14, 29], dtype=int64)
