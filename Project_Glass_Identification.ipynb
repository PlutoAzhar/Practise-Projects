# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Dataset:
df=pd.read_csv('C:/Users/Azhar1/Documents/FlipRobo/Project_practise3/Glass_Identification.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#    ID number  RI: Refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# 0          1               1.52101       13.64           4.49          1.10
# 1          2               1.51761       13.89           3.60          1.36
# 2          3               1.51618       13.53           3.55          1.54
# 3          4               1.51766       13.21           3.69          1.29
# 4          5               1.51742       13.27           3.62          1.24
#
#    Si:Silicon  K: Potassium  Ca: Calcium  Ba: Barium  Fe: Iron  Type of glass
# 0       71.78          0.06         8.75         0.0       0.0              1
# 1       72.73          0.48         7.83         0.0       0.0              1
# 2       72.99          0.39         7.78         0.0       0.0              1
# 3       72.61          0.57         8.22         0.0       0.0              1
# 4       73.08          0.55         8.07         0.0       0.0              1

# %%
df.shape
# Out:
# (214, 11)

# %%
df.dtypes
# Out:
# ID number                 int64
# RI: Refractive index    float64
# Na: Sodium              float64
# Mg: Magnesium           float64
# Al: Aluminum            float64
# Si:Silicon              float64
# K: Potassium            float64
# Ca: Calcium             float64
# Ba: Barium              float64
# Fe: Iron                float64
# Type of glass             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['ID number', 'RI: Refractive index', 'Na: Sodium', 'Mg: Magnesium',
#        'Al: Aluminum', 'Si:Silicon', 'K: Potassium', 'Ca: Calcium',
#        'Ba: Barium', 'Fe: Iron', 'Type of glass'],
#       dtype='object')

# %%
df.describe()
# Out:
#         ID number  RI: Refractive index  Na: Sodium  Mg: Magnesium  \
# count  214.000000            214.000000  214.000000     214.000000
# mean   107.500000              1.518365   13.407850       2.684533
# std     61.920648              0.003037    0.816604       1.442408
# min      1.000000              1.511150   10.730000       0.000000
# 25%     54.250000              1.516522   12.907500       2.115000
# 50%    107.500000              1.517680   13.300000       3.480000
# 75%    160.750000              1.519157   13.825000       3.600000
# max    214.000000              1.533930   17.380000       4.490000
#
#        Al: Aluminum  Si:Silicon  K: Potassium  Ca: Calcium  Ba: Barium  \
# count    214.000000  214.000000    214.000000   214.000000  214.000000
# mean       1.444907   72.650935      0.497056     8.956963    0.175047
# std        0.499270    0.774546      0.652192     1.423153    0.497219
# min        0.290000   69.810000      0.000000     5.430000    0.000000
# ...

# %% [markdown]
# Observations:
#
# There is large difference between 75% and max in Aluminum, Potassium and Calcium.

# %%
df.isnull().sum()
# Out:
# ID number               0
# RI: Refractive index    0
# Na: Sodium              0
# Mg: Magnesium           0
# Al: Aluminum            0
# Si:Silicon              0
# K: Potassium            0
# Ca: Calcium             0
# Ba: Barium              0
# Fe: Iron                0
# Type of glass           0
# dtype: int64

# %% [markdown]
# There are no null values in the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID number             214 non-null    int64
#  1   RI: Refractive index  214 non-null    float64
#  2   Na: Sodium            214 non-null    float64
#  3   Mg: Magnesium         214 non-null    float64
#  4   Al: Aluminum          214 non-null    float64
#  5   Si:Silicon            214 non-null    float64
#  6   K: Potassium          214 non-null    float64
#  7   Ca: Calcium           214 non-null    float64
#  8   Ba: Barium            214 non-null    float64
#  9   Fe: Iron              214 non-null    float64
#  10  Type of glass         214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
df.corr()
# Out:
#                       ID number  RI: Refractive index  Na: Sodium  \
# ID number              1.000000             -0.072209    0.375722
# RI: Refractive index  -0.072209              1.000000   -0.191885
# Na: Sodium             0.375722             -0.191885    1.000000
# Mg: Magnesium         -0.650328             -0.122274   -0.273732
# Al: Aluminum           0.490113             -0.407326    0.156794
# Si:Silicon             0.061232             -0.542052   -0.069809
# K: Potassium           0.003149             -0.289833   -0.266087
# Ca: Calcium            0.090800              0.810403   -0.275442
# Ba: Barium             0.451001             -0.000386    0.326603
# Fe: Iron              -0.072794              0.143010   -0.241346
# Type of glass          0.877357             -0.164237    0.502898
#
#                       Mg: Magnesium  Al: Aluminum  Si:Silicon  K: Potassium  \
# ID number                 -0.650328      0.490113    0.061232      0.003149
# ...

# %% [markdown]
# # Data Visualization

# %%
sns.heatmap(df.isnull(),cmap='crest')
# Out:
# <Axes: >

# %%
# Visualizing the count of Pclass
print(df['Type of glass'].value_counts())
ax=sns.countplot(x='Type of glass',data=df)
plt.show()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type of glass, dtype: int64

# %%
# Applying SMOTE

from imblearn.over_sampling import SMOTE

# %%
dfx=df.iloc[:,0:10]
dfx
# Out:
#      ID number  RI: Refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# 0            1               1.52101       13.64           4.49          1.10
# 1            2               1.51761       13.89           3.60          1.36
# 2            3               1.51618       13.53           3.55          1.54
# 3            4               1.51766       13.21           3.69          1.29
# 4            5               1.51742       13.27           3.62          1.24
# ..         ...                   ...         ...            ...           ...
# 209        210               1.51623       14.14           0.00          2.88
# 210        211               1.51685       14.92           0.00          1.99
# 211        212               1.52065       14.36           0.00          2.02
# 212        213               1.51651       14.38           0.00          1.94
# 213        214               1.51711       14.23           0.00          2.08
#
# ...

# %%
dfy=df.iloc[:,-1]
dfy
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type of glass, Length: 214, dtype: int64

# %%
smt=SMOTE()
trainx,trainy=smt.fit_resample(dfx,dfy)

# %%
trainx.value_counts()
# Out:
# ID number  RI: Refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  Si:Silicon  K: Potassium  Ca: Calcium  Ba: Barium  Fe: Iron
# 1          1.521010              13.640000   4.490000       1.100000      71.780000   0.06          8.750000     0.00        0.00        1
# 178        1.518604              13.863192   2.329609       1.231995      72.974775   0.00          9.508430     0.00        0.00        1
#            1.518479              14.345818   2.277233       1.605107      72.377518   0.00          9.336948     0.00        0.00        1
# 177        1.519310              13.829494   2.406239       1.259585      72.686653   0.00          9.732386     0.00        0.00        1
#            1.519282              13.847539   2.404520       1.291379      72.653141   0.00          9.715201     0.00        0.00        1
#                                                                                                                                         ..
# ...

# %%
trainy.value_counts()
# Out:
# 1    76
# 2    76
# 3    76
# 5    76
# 6    76
# 7    76
# Name: Type of glass, dtype: int64

# %%
# Visualizing data distribution
plt.figure(figsize=(10,6),facecolor='white')
plotnumber=1
for col in df.columns:
    if plotnumber<=10:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df[col],color='m')
        plt.xlabel(col, fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
# Comparing Refractive index and Type of glass

plt.scatter(df['RI: Refractive index'],df['Type of glass'])

# %%
# Comparing Na: Sodium and Type of glass

plt.scatter(df['Na: Sodium'],df['Type of glass'])

# %%
# Comparing Mg: Magnesium and Type of glass

plt.scatter(df['Mg: Magnesium'],df['Type of glass'])

# %%
# Comparing Al: Aluminum and Type of glass

plt.scatter(df['Al: Aluminum'],df['Type of glass'])

# %%
# Comparing Si: Silicon and Type of glass

plt.scatter(df['Si:Silicon'],df['Type of glass'])

# %%
# Comparing K: Potassium and Type of glass

plt.scatter(df['K: Potassium'],df['Type of glass'])

# %%
# Comparing Ca: Calcium and Type of glass

plt.scatter(df['Ca: Calcium'],df['Type of glass'])

# %%
# Comparing Ba: Barium and Type of glass

plt.scatter(df['Ba: Barium'],df['Type of glass'])

# %%
# Comparing Fe: Iron and Type of glass

plt.scatter(df['Fe: Iron'],df['Type of glass'])

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidths=0.1,linecolor='black',annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
x=trainx
y=trainy

# %% [markdown]
# # Finding Best Random State

# %%
#Finding the best random state
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu=0
maxRS=0
for i in range(1,150):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state= i)
    RFR=RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print('Best Accuracy is ',maxAccu,'at random state ',maxRS)
# Out:
# Best Accuracy is  1.0 at random state  1

# %% [markdown]
# # Training & Testing of Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=4)

# %%
x
# Out:
#      ID number  RI: Refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# 0            1              1.521010   13.640000       4.490000      1.100000
# 1            2              1.517610   13.890000       3.600000      1.360000
# 2            3              1.516180   13.530000       3.550000      1.540000
# 3            4              1.517660   13.210000       3.690000      1.290000
# 4            5              1.517420   13.270000       3.620000      1.240000
# ..         ...                   ...         ...            ...           ...
# 451        199              1.516068   14.962078       0.000000      2.511261
# 452        197              1.515383   14.254504       0.000000      2.670458
# 453        194              1.515672   14.416860       0.000000      2.563017
# 454        188              1.523129   13.484829       3.304011      1.256203
# 455        194              1.517041   14.671191       0.000000      1.991704
#
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 451    7
# 452    7
# 453    7
# 454    7
# 455    7
# Name: Type of glass, Length: 456, dtype: int64

# %% [markdown]
# # Using various models

# %%
# Using MNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

mnb=MultinomialNB()
mnb.fit(x_train,y_train)
predmnb=mnb.predict(x_test)
print(accuracy_score(y_test,predmnb))
print(confusion_matrix(y_test,predmnb))
print(classification_report(y_test,predmnb))
# Out:
# 0.8759124087591241
# [[18  5  0  0  0  0]
#  [ 0 19  6  1  0  0]
#  [ 0  0 23  0  0  0]
#  [ 0  0  0 17  0  1]
#  [ 0  0  0  0 21  0]
#  [ 0  0  2  2  0 22]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.78      0.88        23
#            2       0.79      0.73      0.76        26
#            3       0.74      1.00      0.85        23
#            5       0.85      0.94      0.89        18
#            6       1.00      1.00      1.00        21
#            7       0.96      0.85      0.90        26
#
#     accuracy                           0.88       137
#    macro avg       0.89      0.88      0.88       137
# weighted avg       0.89      0.88      0.88       137

# %%
# Using Logistic Regression

from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
lg.fit(x_train,y_train)
predlg=lg.predict(x_test)
print(accuracy_score(y_test,predlg))
print(confusion_matrix(y_test,predlg))
print(classification_report(y_test,predlg))
# Out:
# 1.0
# [[23  0  0  0  0  0]
#  [ 0 26  0  0  0  0]
#  [ 0  0 23  0  0  0]
#  [ 0  0  0 18  0  0]
#  [ 0  0  0  0 21  0]
#  [ 0  0  0  0  0 26]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        23
#            2       1.00      1.00      1.00        26
#            3       1.00      1.00      1.00        23
#            5       1.00      1.00      1.00        18
#            6       1.00      1.00      1.00        21
#            7       1.00      1.00      1.00        26
#
#     accuracy                           1.00       137
#    macro avg       1.00      1.00      1.00       137
# weighted avg       1.00      1.00      1.00       137

# %%
# Using SVC model:

from sklearn.svm import SVC
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.7226277372262774
# [[23  0  0  0  0  0]
#  [ 1 19  6  0  0  0]
#  [ 0  0 16  7  0  0]
#  [ 0  0  0 18  0  0]
#  [ 0  0  0 17  4  0]
#  [ 0  0  0  0  7 19]]
#               precision    recall  f1-score   support
#
#            1       0.96      1.00      0.98        23
#            2       1.00      0.73      0.84        26
#            3       0.73      0.70      0.71        23
#            5       0.43      1.00      0.60        18
#            6       0.36      0.19      0.25        21
#            7       1.00      0.73      0.84        26
#
#     accuracy                           0.72       137
#    macro avg       0.75      0.72      0.70       137
# weighted avg       0.77      0.72      0.72       137

# %%
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.927007299270073
# [[23  0  0  0  0  0]
#  [ 3 20  3  0  0  0]
#  [ 0  0 23  0  0  0]
#  [ 0  0  0 17  1  0]
#  [ 0  0  0  0 21  0]
#  [ 0  0  0  0  3 23]]
#               precision    recall  f1-score   support
#
#            1       0.88      1.00      0.94        23
#            2       1.00      0.77      0.87        26
#            3       0.88      1.00      0.94        23
#            5       1.00      0.94      0.97        18
#            6       0.84      1.00      0.91        21
#            7       1.00      0.88      0.94        26
#
#     accuracy                           0.93       137
#    macro avg       0.93      0.93      0.93       137
# weighted avg       0.94      0.93      0.93       137

# %%
# Using KNN model:
# k =10

from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.9927007299270073
# [[23  0  0  0  0  0]
#  [ 1 25  0  0  0  0]
#  [ 0  0 23  0  0  0]
#  [ 0  0  0 18  0  0]
#  [ 0  0  0  0 21  0]
#  [ 0  0  0  0  0 26]]
#               precision    recall  f1-score   support
#
#            1       0.96      1.00      0.98        23
#            2       1.00      0.96      0.98        26
#            3       1.00      1.00      1.00        23
#            5       1.00      1.00      1.00        18
#            6       1.00      1.00      1.00        21
#            7       1.00      1.00      1.00        26
#
#     accuracy                           0.99       137
#    macro avg       0.99      0.99      0.99       137
# weighted avg       0.99      0.99      0.99       137

# %%
# Using Decision Tree model:

from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.9927007299270073
# [[23  0  0  0  0  0]
#  [ 1 25  0  0  0  0]
#  [ 0  0 23  0  0  0]
#  [ 0  0  0 18  0  0]
#  [ 0  0  0  0 21  0]
#  [ 0  0  0  0  0 26]]
#               precision    recall  f1-score   support
#
#            1       0.96      1.00      0.98        23
#            2       1.00      0.96      0.98        26
#            3       1.00      1.00      1.00        23
#            5       1.00      1.00      1.00        18
#            6       1.00      1.00      1.00        21
#            7       1.00      1.00      1.00        26
#
#     accuracy                           0.99       137
#    macro avg       0.99      0.99      0.99       137
# weighted avg       0.99      0.99      0.99       137

# %%
# Using Random Forest classifier:

from sklearn.ensemble import RandomForestClassifier
RF=DecisionTreeClassifier()
RF.fit(x_train,y_train)
RF.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.9927007299270073
# [[23  0  0  0  0  0]
#  [ 1 25  0  0  0  0]
#  [ 0  0 23  0  0  0]
#  [ 0  0  0 18  0  0]
#  [ 0  0  0  0 21  0]
#  [ 0  0  0  0  0 26]]
#               precision    recall  f1-score   support
#
#            1       0.96      1.00      0.98        23
#            2       1.00      0.96      0.98        26
#            3       1.00      1.00      1.00        23
#            5       1.00      1.00      1.00        18
#            6       1.00      1.00      1.00        21
#            7       1.00      1.00      1.00        26
#
#     accuracy                           0.99       137
#    macro avg       0.99      0.99      0.99       137
# weighted avg       0.99      0.99      0.99       137

# %%
# Comparing Accuracy scores of all models:

Accuracy=pd.DataFrame({'Model':['MNB',"Logistic Regression",'SVC-rbf','SVC-poly','KNN','Decision Tree','Random Forest Classifier'],'Accuracy':[0.8759,1.0,0.7226,0.9270,0.9927,0.9927,0.9927]})
Accuracy
# Out:
#                       Model  Accuracy
# 0                       MNB    0.8759
# 1       Logistic Regression    1.0000
# 2                   SVC-rbf    0.7226
# 3                  SVC-poly    0.9270
# 4                       KNN    0.9927
# 5             Decision Tree    0.9927
# 6  Random Forest Classifier    0.9927

# %%
from sklearn.model_selection import cross_val_score

# %%
# Checking CV score for MNB
score=cross_val_score(mnb,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is ",accuracy_score(y_test,predmnb) - score.mean())
# Out:
# [0.93478261 0.96703297 0.94505495 0.89010989 0.69230769]
# 0.8858576206402293
# Difference between Accuracy score and cross validation score is  -0.009945211881105198

# %%
# Checking CV score for LG
score=cross_val_score(lg,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is ",accuracy_score(y_test,predmnb) - score.mean())
# Out:
# [0.91304348 1.         1.         1.         0.79120879]
# 0.9408504538939322
# Difference between Accuracy score and cross validation score is  -0.06493804513480805

# %%
# Checking CV score for SVC
score=cross_val_score(svc,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is ",accuracy_score(y_test,predmnb) - score.mean())
# Out:
# [0.79347826 0.98901099 0.96703297 0.96703297 0.89010989]
# 0.9213330148112757
# Difference between Accuracy score and cross validation score is  -0.04542060605215159

# %%
# Checking CV score for KNN
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is ",accuracy_score(y_test,predmnb) - score.mean())
# Out:
# [0.92391304 1.         1.         1.         0.84615385]
# 0.9540133779264213
# Difference between Accuracy score and cross validation score is  -0.07810096916729714

# %%
# Checking CV score for DTC
score=cross_val_score(dtc,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is ",accuracy_score(y_test,predmnb) - score.mean())
# Out:
# [0.91304348 1.         1.         1.         0.86813187]
# 0.9562350692785475
# Difference between Accuracy score and cross validation score is  -0.08032266051942338

# %%
# Checking CV score for RandomForest
score=cross_val_score(RF,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is ",accuracy_score(y_test,predmnb) - score.mean())
# Out:
# [0.91304348 1.         1.         1.         0.86813187]
# 0.9562350692785475
# Difference between Accuracy score and cross validation score is  -0.08032266051942338

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(dtc,'Project_Glass_Identification.pkl')
# Out:
# ['Project_Glass_Identification.pkl']

# %% [markdown]
# # Predicting the saved model

# %%
model=joblib.load('Project_Glass_Identification.pkl')

#Prediction
prediction=model.predict(x_test)
prediction
# Out:
# array([7, 7, 5, 5, 6, 7, 7, 1, 5, 1, 7, 2, 6, 2, 7, 3, 7, 6, 7, 7, 1, 7,
#        3, 1, 1, 5, 2, 7, 1, 1, 2, 3, 6, 5, 1, 5, 5, 3, 2, 5, 7, 2, 2, 1,
#        2, 7, 3, 3, 3, 7, 3, 1, 1, 6, 5, 7, 2, 7, 7, 6, 5, 2, 2, 6, 2, 3,
#        1, 6, 3, 6, 1, 7, 3, 2, 5, 2, 6, 1, 2, 1, 5, 6, 3, 3, 6, 6, 3, 1,
#        7, 2, 5, 6, 3, 2, 1, 3, 6, 3, 5, 7, 1, 1, 5, 5, 2, 1, 6, 1, 2, 6,
#        3, 1, 6, 7, 6, 3, 7, 2, 3, 2, 6, 7, 1, 2, 2, 3, 7, 2, 5, 6, 7, 5,
#        3, 2, 1, 3, 7], dtype=int64)
